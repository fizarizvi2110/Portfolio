# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Fall 2023, Sections 002
# </span>
# </center></b>
# <br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Homework 2
# </span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# # Setup

# %%
# %load_ext sql
# %sql mysql+pymysql://root:dbuserdbuser@localhost
# %sql SELECT 1
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(1,)]

# %%
import csv
import copy

import pandas as pd
import pymysql

# %%
sql_conn = pymysql.connect(
    user="root",
    password="dbuserdbuser",
    host="localhost",
    port=3306,
    cursorclass=pymysql.cursors.DictCursor,
    autocommit=True)

cur = sql_conn.cursor()
res = cur.execute("SELECT 1")
res = cur.fetchall()
res
# Out:
# [{'1': 1}]

# %% [markdown]
# # Written Questions

# %% [markdown]
# ## W1
#
# Codd's Third Rule states, "Null values (distinct from the empty character string or a string of blank characters and distinct from zero or any other number) are supported in fully relational DBMS for representing missing information and inapplicable information in a systematic way, independent of data type."
#
# Briefly explain the value of this rule and provide two examples.

# %% [markdown]
# Answer: Codd's Third Rule allows for the representation of absent data in a meaningful way to make a dataset complete and accessible even though certain information is missing.
# One example is if a customer's address is unknown, to set its value to null. That way there is a way to understand a value is missing within the data. Another example is if an employee's birthday is unknown, to set the string value to null so that those who access and manipulate the database are able to see the date of birth is missing.

# %% [markdown]
# ## W2
#
# Codd's 6th rule states, "All views that are theoretically updatable are also updatable by the system."
#
# Using the following table definition, use SQL (```CREATE VIEW```) to define:
# 1. Two views of the table that are theoretically not possible to update.
# 2. One view that is theoretically possible to update.
#
# You do not need to execute the create statement. We are focusing on your understanding.
#
#
# ```
# create table midterm_students
# (
# 	social_security_no char(9) not null
# 		primary key,
# 	last_name varchar(64) null,
# 	first_name varchar(64) null,
# 	enrollment_year year null,
# 	total_credits int null
# );
# ```

# %% [markdown]
# Answer:
# 1. Two views that are not theoretically possible to update are as follows. First, suppose you create a view to find the average total credits for students and save it as a variable. Since you have averaged total_credits for all students, updating the view is not possible since it would be difficult for the system to access the original data now that it has been aggregated. Another view that is not theoretically possible to update is if you joined a tuple, for example social_security_no, with another table. It would be theoretically impossible for the system to update the view because it would be difficult to determine how the update affects the two tables since they have been joined in the view. A view that would be theoretically possible to update is if you only selected students from a certain enrollment_year with the select operation. It is theoretically possible, then, for the system to handle updates since it is a simple operation from a single table.

# %% [markdown]
# ## W3
#
# In the Columbia University [directory of classes](http://www.columbia.edu/cu/bulletin/uwb/#/cu/bulletin/uwb/subj/COMS/W4111-20233-002), the "Section Key" for this course is ```20233COMS4111W002```.
#
# - Explain why having a column ```section_key varchar(17)``` that holds section key values is non-atomic.
# - Give two explanations for why using the section key (non-atomic data) for a column causes problems.

# %% [markdown]
# Answer: section_key is non-atomic because it can be broken down into meaningful parts, for example: 2023 stands for the year COMS is the department, 4111 is the course number, and 002 is for section 2.
# This is a problem because it creates repeated data, for example if it needs to be updated if there is a change to the section etc. the entire string must be updated rather than just the section. Another issue is that querying becomes more difficult. For example, to query for just a certain year, you would need to extract the data from the string rather than just using a year variable.

# %% [markdown]
# ## W4
#
# Briefly explain the differences between
#
# - Database stored procedures
# - Database functions
# - Database triggers

# %% [markdown]
# Answer: Stored procedures are ones that are stored in the database and executed from SQL statements, and can be defined either by the procedural component of SQL, or by an external programming language (Lecture Notes). The name and its arguments are used to define procedures.
# Database functions are like stored procedures but return a single value or a table. They typically are calculations or data manipulations to be used multiple times in querying.
# Database triggers are statements that are executed automatically by the system as a response to a modification of the database. One can be designed by defining when the trigger is activated and what actions it should execute when it is.

# %% [markdown]
# ## W5
#
# Consider the `db_book` schema, which we have used in class and previous HWs.
#
# 1. Is any entity type in the schema a _weak entity_? If yes, list one of them.
# 2. In database design, using ```ON DELETE CASCADE``` may not be desired behavior/design. Why is it more likely that ```ON DELETE CASCADE``` is the correct behavior for weak entities when the referenced row is deleted?

# %% [markdown]
# Answer: Yes, teaches is a weak entity because all of its primary keys are entirely dependent on section and instructor. Therefore, teaches is a weak entity because its existence depends entirely on other entities existing.
# ON DELETE CASCADE is the correct behavior for weak entities when the referenced row is deleted because when the referenced row is deleted, it will automatically delete the associated weak entities to mantain referential integrity in the database.

# %% [markdown]
# ## W6
#
# Briefly explain the differences between:
# 1. _Candidate Key_ and _Super Key_
# 2. _Primary Key_ and _Unique Key_
# 3. _Natural Key_ and _Surrogate Key_

# %% [markdown]
# Answer:
# 1. A super key of a relation is a set of attributes for an entity that are sufficient to identify a unique tuple of each possible relation, while a candidate key is a minimal super key that may be selected as the primary key.
# 2. A primary key is typically selected from one of the candidate keys and is used to uniquely identify tuples in the relation, while a unique key is states the combination of attributes that can uniquely identify each tuple in a table. A unique key with all not null columns is a primary key, but unlike a primary key, a unique key can have a null value.
# 3. A natural key is derived from real-world data and often carry meaning. They are used to uniquely identify a tuple in a dataset, while a surrogate key is not derived from real-world data but rather, generated and without inherent meaning, but are also used to uniquely identify a tuple in a dataset.

# %% [markdown]
# ## W7
#
# 1. Briefly explain the concept of a _database cursor_.
# 2. Why is using a cursor helpful for applications processing database information?

# %% [markdown]
# Answer: A database cursor is an object that allows traversal over records in a database, and can be used to identify records in a database acting as a pointer of sorts. It can read records or modify them.
# Using a cursor is helpful for applications processing database information because in a large dataset, it allows incremental loading and allows you to fetch data in real-time. Also, it allows precision for applications in dealing with data row-by-row and allows for performing operations that are individualized for specific records.

# %% [markdown]
# ## W8
#
# Give two reasons for using an associate entity to implement a relationship instead of a foreign key.

# %% [markdown]
# Answer: An associative entity can decompose a many to many relation into a two one-to-many relations for a more structured database than a foreign key. Another reason for using an associative entity is that you can easily include attributes that exist in both entities they share a relation with while a foreign key cannot.

# %% [markdown]
# ## W9
#
# Briefly explain the following data modeling concepts:
#
# - Conceptual model
# - Logical model
# - Physical model

# %% [markdown]
# Answer: A conceptual model is a higher-level broader view of how data will be represented through entities and their relations. It does not specificy the technicality of how data will be stored and its types.
# A logical model focuses more on how data is structured, specifying how entities will hold attibutes, keys, and how to maximize data integrity in its design.
# A physical model showcases the fine details of how data is to be represented, stored, and implemented in a specific program, including indexes, constraints and the data types.

# %% [markdown]
# ## W10
#
# Briefly explain the difference between _data definition language_ and _data manipulation language_.

# %% [markdown]
# Answer: Data defintion language is used to manage and define the structure of data with create, drop, and alter statements. Data manipulation language is used to manipulate the data through select, insert, delete, and update statements.

# %% [markdown]
# # DDL

# %% [markdown]
# - You have a logical ER diagram below.
#
#
# - You need to use DDL to define a schema that realizes the model.
#
#
# - Logical models are not specific enough for direct implementation. This means that:
#     - You will have to assign concrete types to columns and choose things like ```GENERATED```, ```DEFAULT```, etc.
#     - You have to make assumptions about things like ```NOT NULL```.
#     - You may have to make other design and implementation choices. **This means that there is no single correct answer.**
#
#
# - In addition to the key constraints, you must also implement the following constraints:
#     - `id` values must be an auto-incrementing integer
#     - ```email``` must contain an ```@``` and end in ```.edu```
#     - `rank` must be one of `Member` or `Admin`
#     - ```num_stars``` must be between 1 and 5

# %% [markdown]
# | <img src="./book_club_er.png"> |
# | :---: |
# | __ER Diagram__ |

# %% [markdown]
# _Design Decisions, Notes, etc._ Document any assumption or decisions.

# %% [markdown]
# Execute your DDL in the cell below.

# %% [markdown]
# Assume each author's name is unique.

# %%
# %%sql
#
# DROP SCHEMA IF EXISTS f23_hw2_er;
# CREATE SCHEMA f23_hw2_er;
# USE f23_hw2_er;
#
# CREATE TABLE Author (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     first_name VARCHAR(50) NOT NULL,
#     last_name VARCHAR(50) NOT NULL,
#     biography VARCHAR(255) DEFAULT 'No biography available',
#     UNIQUE (first_name, last_name)
# );
#
# CREATE TABLE Book (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     title VARCHAR(255) NOT NULL,
#     description TEXT,
#     publish_date DATE NOT NULL,
#     author INT,
#     FOREIGN KEY (author) REFERENCES Author(id)
# );
#
# CREATE TABLE User (
#     email VARCHAR(100) PRIMARY KEY,
#     first_name VARCHAR(50) NOT NULL,
#     last_name VARCHAR(50) NOT NULL
# );
#
# CREATE TABLE BookClub (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     book INT,
#     start_date DATE NOT NULL,
#     end_date DATE NOT NULL,
#     FOREIGN KEY (book) REFERENCES Book(id)
# );
#
# CREATE TABLE Member (
#     user_email VARCHAR(100),
#     book_club_id INT,
#     `rank` ENUM('Member', 'Admin') NOT NULL,
#     PRIMARY KEY (user_email, book_club_id),
#     FOREIGN KEY (user_email) REFERENCES User(email),
#     FOREIGN KEY (book_club_id) REFERENCES BookClub(id)
# );
#
# CREATE TABLE Review (
#     user_email VARCHAR(100),
#     book_id INT,
#     num_stars INT CHECK (num_stars BETWEEN 1 AND 5) NOT NULL,
#     description TEXT,
#     PRIMARY KEY (user_email, book_id),
#     FOREIGN KEY (user_email) REFERENCES User(email),
#     FOREIGN KEY (book_id) REFERENCES Book(id)
# );
#
# ALTER TABLE User
# ADD CONSTRAINT check_email_format_user CHECK (email LIKE '%@%.edu');
#
# ALTER TABLE Review
# ADD CONSTRAINT check_email_format_review CHECK (user_email LIKE '%@%.edu');
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 1 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# # SQL

# %% [markdown]
# ## Overview
#
# - The directory contains a file ```people_info.csv```. The columns are
#     - ```first_name```
#     - ```middle_name```
#     - ```last_name```
#     - ```email```
#     - ```employee_type,``` which can be one of ```Professor```, ```Lecturer```, ```Staff```. The value is empty if the person is a student.
#     - ```enrollment_year``` which must be in the range ```2016-2023```. The value is empty if the person is an employee.
#
#
# - If ```enrollment_year``` is not NULL, the person is a ```Student``` and ```employee_type``` must be NULL. If ```employee_type``` is not NULL, then the person is a ```Employee``` and ```enrollment_year``` must be NULL.
#
#
# - You must implement a [two-table](https://vertabelo.com/blog/inheritance-in-a-relational-database/) solution to the inheritance pattern. This means that your solution will have tables ```student``` and ```employee```, and have a view ```people```.
#
#
# - **You must demonstrate correct implementation by loading the data, using select statements, attempting insert/update/delete, ...**

# %%
# %%sql
#
# DROP SCHEMA IF EXISTS f23_hw2;
# CREATE SCHEMA f23_hw2;
# USE f23_hw2;
#
# CREATE TABLE student (
#     id INT PRIMARY KEY,
#     first_name VARCHAR(50),
#     middle_name VARCHAR(50),
#     last_name VARCHAR(50),
#     email VARCHAR(100),
#     enrollment_year INT,
#     CHECK (enrollment_year BETWEEN 2016 AND 2023)
# );
#
# CREATE TABLE employee (
#     id INT PRIMARY KEY,
#     first_name VARCHAR(50),
#     middle_name VARCHAR(50),
#     last_name VARCHAR(50),
#     email VARCHAR(100),
#     employee_type ENUM('Professor', 'Lecturer', 'Staff')
# );
#
#
# CREATE VIEW people AS
# SELECT
#     'student' AS user_type,
#     id,
#     first_name,
#     middle_name,
#     last_name,
#     email,
#     enrollment_year,
#     NULL AS employee_type
# FROM student
# UNION ALL
# SELECT
#     'employee' AS user_type,
#     id,
#     first_name,
#     middle_name,
#     last_name,
#     email,
#     NULL AS enrollment_year,
#     employee_type
# FROM employee;
# Out:
#  * mysql+pymysql://root:***@localhost
# 3 rows affected.
# 1 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## Tables and View
#
# - You must implement the two tables and view, including reasonable data types and constraints. **This must include an additional column ```uni``` that we explain below.** You may add additional columns and triggers if that helps.
#     1. `uni` is the primary key.
#     2. ```employee_type``` must be one of ```Professor```, ```Lecturer```, ```Staff```.
#     3. ```enrollment_year``` must be in the range ```2016-2023``` inclusive.
#     4. Only ```middle_name``` can be null.
#     5. ```email``` must be unique over both ```student``` and ```employee```. Note that this constraint should be checked when inserting new rows _and_ updating existing rows.

# %%
# %%sql
#
# DROP SCHEMA IF EXISTS f23_hw2;
# CREATE SCHEMA f23_hw2;
#
# USE f23_hw2;
#
# CREATE TABLE student (
#     uni VARCHAR(10) PRIMARY KEY,
#     first_name VARCHAR(50) NOT NULL,
#     middle_name VARCHAR(50),
#     last_name VARCHAR(50) NOT NULL,
#     email VARCHAR(100) UNIQUE NOT NULL,
#     enrollment_year INT CHECK (enrollment_year BETWEEN 2016 AND 2023),
#     additional_student_column VARCHAR(255),
#     INDEX (email)
# );
#
# CREATE TABLE employee (
#     uni VARCHAR(10) PRIMARY KEY,
#     first_name VARCHAR(50) NOT NULL,
#     middle_name VARCHAR(50),
#     last_name VARCHAR(50) NOT NULL,
#     email VARCHAR(100) UNIQUE NOT NULL,
#     employee_type ENUM('Professor', 'Lecturer', 'Staff'),
#     additional_employee_column VARCHAR(255),
#     INDEX (email)
# );
#
# CREATE VIEW people AS
# SELECT
#     'student' AS user_type,
#     uni,
#     first_name,
#     middle_name,
#     last_name,
#     email,
#     enrollment_year,
#     NULL AS employee_type
# FROM student
# UNION ALL
# SELECT
#     'employee' AS user_type,
#     uni,
#     first_name,
#     middle_name,
#     last_name,
#     email,
#     NULL AS enrollment_year,
#     employee_type
# FROM employee;
# Out:
#  * mysql+pymysql://root:***@localhost
# 3 rows affected.
# 1 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## UNI
#
# - `uni`:
#     1. Must be of the form `fml####`, where `f` is the first letter (lowercased) of the first name, `m` is the first letter of the middle name (if not NULL), `l` is the first letter of the last name, and `#` is a number.
#     2. For any combination of letters, the numbers following the letters must start at 1 and increase. That is, `dff0001`, `ab0001`, `dff0002`, `cd0001`, `cad0001`, `cd0002`, ...
#     3. You must implement a function to generate the ```uni```.
#     4. You must implement triggers on the relevant tables to automatically set the ```uni``` during an insert.
#     5. You must implement triggers that adjust the `uni` if a person's initials change during an update.
#     6. You must implement logic that prevent inserts from directly setting the `uni` and updates from directly changing the ```uni```.

# %%
# %%sql
#
# USE f23_hw2;
# DROP FUNCTION IF EXISTS generate_uni;
#
# CREATE FUNCTION generate_uni(first_name VARCHAR(50), middle_name VARCHAR(50), last_name VARCHAR(50)) RETURNS VARCHAR(10)
# DETERMINISTIC
# BEGIN
#     DECLARE initials VARCHAR(3);
#     DECLARE count_val INT;
#
#     SET initials = LOWER(SUBSTRING(first_name, 1, 1));
#     IF middle_name IS NOT NULL THEN
#         SET initials = CONCAT(initials, SUBSTRING(middle_name, 1, 1));
#     END IF;
#     SET initials = CONCAT(initials, SUBSTRING(last_name, 1, 1));
#
#     SET count_val = 1;
#
#     SELECT COALESCE(MAX(CAST(SUBSTRING(uni, 4) AS SIGNED)), 0) + 1 INTO count_val
#     FROM (
#         SELECT uni FROM student WHERE uni LIKE CONCAT(initials, '%%%%')
#         UNION ALL
#         SELECT uni FROM employee WHERE uni LIKE CONCAT(initials, '%%%%')
#     ) AS temp;
#
#     RETURN CONCAT(initials, LPAD(count_val, 4, '0'));
# END;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## Procedures
#
# - You must implement four stored procedures. The implementations of the four procedures are almost identical.
#     1. The procedures are:
#         1. `create_student(first_name, middle_name, last_name, email, enrollment_year, uni)`
#         2. `create_employee(first_name, middle_name, last_name, email, employee_type, uni)`
#         3. `update_student(uni, first_name, middle_name, last_name, email, enrollment_year)`
#         4. `update_employee(uni, first_name, middle_name, last_name, email, employee_type)`
#     2. For updates, the procedures ignore input parameters that are NULL and only apply the non-NULL values. The procedures do not update the ```uni```.
#     3. The create procedures return the ```uni``` as an out value.

# %%
# %%sql
#
# DROP PROCEDURE IF EXISTS create_student;
# DROP PROCEDURE IF EXISTS create_employee;
# DROP PROCEDURE IF EXISTS update_student;
# DROP PROCEDURE IF EXISTS update_employee;
#
# CREATE PROCEDURE create_student(
#     IN first_name VARCHAR(50),
#     IN middle_name VARCHAR(50),
#     IN last_name VARCHAR(50),
#     IN email VARCHAR(100),
#     IN enrollment_year INT,
#     OUT uni VARCHAR(10)
# )
# BEGIN
#     SET uni = generate_uni(first_name, middle_name, last_name);
#
#     INSERT INTO student (first_name, middle_name, last_name, email, enrollment_year, uni)
#     VALUES (first_name, middle_name, last_name, email, enrollment_year, uni);
# END;
#
# CREATE PROCEDURE create_employee(
#     IN first_name VARCHAR(50),
#     IN middle_name VARCHAR(50),
#     IN last_name VARCHAR(50),
#     IN email VARCHAR(100),
#     IN employee_type ENUM('Professor', 'Lecturer', 'Staff'),
#     OUT uni VARCHAR(10)
# )
# BEGIN
#     SET uni = generate_uni(first_name, middle_name, last_name);
#
#     INSERT INTO employee (first_name, middle_name, last_name, email, employee_type, uni)
#     VALUES (first_name, middle_name, last_name, email, employee_type, uni);
# END;
#
# CREATE PROCEDURE update_student(
#     IN uni_param VARCHAR(10),
#     IN first_name_param VARCHAR(50),
#     IN middle_name_param VARCHAR(50),
#     IN last_name_param VARCHAR(50),
#     IN email_param VARCHAR(100),
#     IN enrollment_year_param INT
# )
# BEGIN
#     UPDATE student
#     SET
#         first_name = COALESCE(first_name_param, first_name),
#         middle_name = COALESCE(middle_name_param, middle_name),
#         last_name = COALESCE(last_name_param, last_name),
#         email = COALESCE(email_param, email),
#         enrollment_year = COALESCE(enrollment_year_param, enrollment_year)
#     WHERE uni = uni_param;
# END;
#
# CREATE PROCEDURE update_employee(
#     IN uni_param VARCHAR(10),
#     IN first_name_param VARCHAR(50),
#     IN middle_name_param VARCHAR(50),
#     IN last_name_param VARCHAR(50),
#     IN email_param VARCHAR(100),
#     IN employee_type_param ENUM('Professor', 'Lecturer', 'Staff')
# )
# BEGIN
#     UPDATE employee
#     SET
#         first_name = COALESCE(first_name_param, first_name),
#         middle_name = COALESCE(middle_name_param, middle_name),
#         last_name = COALESCE(last_name_param, last_name),
#         email = COALESCE(email_param, email),
#         employee_type = COALESCE(employee_type_param, employee_type)
#     WHERE uni = uni_param;
# END;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## Security
#
# - You must create a new user `general_user` and use security to allow it to perform only `SELECT` and `EXECUTE` operations (i.e., no ```INSERT```, ```DELETE```, and ```UPDATE``` operations).

# %%
# %%sql
#
# DROP USER 'general_user'@'%';
#
# GRANT CREATE USER ON *.* TO 'root'@'localhost';
#
# CREATE USER 'general_user'@'%' IDENTIFIED BY 'dbuserdbuser';
#
# GRANT SELECT ON f23_hw2.* TO 'general_user'@'%';
#
# GRANT EXECUTE ON PROCEDURE f23_hw2.create_student TO 'general_user'@'%';
# GRANT EXECUTE ON PROCEDURE f23_hw2.create_employee TO 'general_user'@'%';
# GRANT EXECUTE ON PROCEDURE f23_hw2.update_student TO 'general_user'@'%';
# GRANT EXECUTE ON PROCEDURE f23_hw2.update_employee TO 'general_user'@'%';
#
# REVOKE INSERT, UPDATE, DELETE ON f23_hw2.* FROM 'general_user'@'%';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## Data Insertion

# %%
# %%sql
#
# # The following assumes that you have created everything properly
#
# DELETE FROM f23_hw2.student;
# DELETE FROM f23_hw2.employee;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
people_info = []
with open("people_info.csv", "r") as in_file:
    d_rdr = csv.DictReader(in_file)
    for r in d_rdr:
        people_info.append(dict(r))

people_info_df = pd.DataFrame(people_info)
people_info_df
# Out:
#    first_name middle_name  last_name                           email  \
# 0     Sanders      Arline   Breckell           abreckell1x@fotki.com
# 1       Zared                Fenelon       afenelona@themeforest.net
# 2     Ethelin                 Fidele             afidele12@google.ru
# 3      Bibbye     Annabal   Guesford           aguesfordb@tumblr.com
# 4       Xenia     Ardella       Kief                  akieft@free.fr
# ..        ...         ...        ...                             ...
# 95      Norry              Rubinchik  trubinchik16@howstuffworks.com
# 96       Doug               Medforth       vmedforth1o@homestead.com
# 97      Gerty              O'Donegan        vodoneganf@clickbank.net
# 98   Anabelle      Wallas     Quimby               wquimby1c@nba.com
# 99      Sasha         Win     Ruffli         wruffli2q@wordpress.com
#
#    employee_type enrollment_year
# 0      Professor
# 1                           2021
# 2       Lecturer
# 3                           2018
# ...

# %%
# If you have defined your procedures, functions, tables, and constraints correctly, you can use the function below
# to load your data.

def add_person(p):
    """
    p is a dictionary containing the column values for either a student or an employee.
    """
    
    cur = sql_conn.cursor()
    
    # This function changes the data, converting '' to None.
    # So, we make a copy and change the copy.
    p_dict = copy.copy(p)
    for k,v in p_dict.items():
        if v == '':
            p_dict[k] = None
    
    # Is the person a student?
    #
    if p_dict['employee_type'] is None:
        
        # This provides a hint for what your stored procedure will look like.
        res = cur.callproc("f23_hw2.create_student",
                           # The following are in parameters
                          (p_dict['first_name'],
                          p_dict['middle_name'],
                          p_dict['last_name'],
                           p_dict['email'],
                          p_dict['enrollment_year'],
                           # The following are out parameters for uni.
                          None))
        
        # After the procedure executes, the following query will select the out values.
        res = cur.execute("""SELECT @_f23_hw2.create_student_5""")
        result = cur.fetchall()
    
    # The following does the same for employee.
    elif p_dict['enrollment_year'] is None:
        res = cur.callproc("f23_hw2.create_employee",
                          (p_dict['first_name'],
                          p_dict['middle_name'],
                          p_dict['last_name'],
                           p_dict['email'],
                          p_dict['employee_type'],
                          None))
        res = cur.execute("""SELECT @_f23_hw2.create_student_5""")
        result = cur.fetchall()
    else:
        print("Something went wrong")
        result = None
    
    sql_conn.commit()
    cur.close()
    return result

# %%
for p in people_info:
    add_person(p)

# %%
# Test that we loaded people
# %sql SELECT * FROM people
# Out:
#  * mysql+pymysql://root:***@localhost
# 100 rows affected.
# [('student', 'aEB0001', 'Avie', 'Else', 'Blissitt', 'eblissitti@youtu.be', 2018, None),
#  ('student', 'aHA0001', 'Abbey', 'Helge', 'Anyene', 'hanyene2c@newsvine.com', 2019, None),
#  ('student', 'aWQ0001', 'Anabelle', 'Wallas', 'Quimby', 'wquimby1c@nba.com', 2022, None),
#  ('student', 'bAG0001', 'Bibbye', 'Annabal', 'Guesford', 'aguesfordb@tumblr.com', 2018, None),
#  ('student', 'bB0001', 'Base', None, 'Baybutt', 'bbaybutty@tmall.com', 2021, None),
#  ('student', 'bCE0001', 'Barry', 'Cullin', 'Elias', 'celias1k@scribd.com', 2018, None),
#  ('student', 'bCM0001', 'Brigida', 'Cameron', 'Maclean', 'cmaclean13@mac.com', 2019, None),
#  ('student', 'bEG0001', 'Bank', 'Elane', 'Guerola', 'eguerola29@blogger.com', 2021, None),
#  ('student', 'cEG0001', 'Courtnay', 'Elbert', 'Gillespie', 'egillespie2m@slideshare.net', 2020, None),
#  ('student', 'cFH0001', 'Charline', 'Ferd', 'Hartell', 'fhartell1@meetup.com', 2020, None),
# ...

# %%
# Test that we loaded students
# %sql SELECT * FROM student
# Out:
#  * mysql+pymysql://root:***@localhost
# 50 rows affected.
# [('aEB0001', 'Avie', 'Else', 'Blissitt', 'eblissitti@youtu.be', 2018, None),
#  ('aHA0001', 'Abbey', 'Helge', 'Anyene', 'hanyene2c@newsvine.com', 2019, None),
#  ('aWQ0001', 'Anabelle', 'Wallas', 'Quimby', 'wquimby1c@nba.com', 2022, None),
#  ('bAG0001', 'Bibbye', 'Annabal', 'Guesford', 'aguesfordb@tumblr.com', 2018, None),
#  ('bB0001', 'Base', None, 'Baybutt', 'bbaybutty@tmall.com', 2021, None),
#  ('bCE0001', 'Barry', 'Cullin', 'Elias', 'celias1k@scribd.com', 2018, None),
#  ('bCM0001', 'Brigida', 'Cameron', 'Maclean', 'cmaclean13@mac.com', 2019, None),
#  ('bEG0001', 'Bank', 'Elane', 'Guerola', 'eguerola29@blogger.com', 2021, None),
#  ('cEG0001', 'Courtnay', 'Elbert', 'Gillespie', 'egillespie2m@slideshare.net', 2020, None),
#  ('cFH0001', 'Charline', 'Ferd', 'Hartell', 'fhartell1@meetup.com', 2020, None),
#  ('cV0001', 'Carroll', None, 'Venables', 'rvenablesu@friendfeed.com', 2019, None),
# ...

# %%
# Test that we loaded employees
# %sql SELECT * FROM employee
# Out:
#  * mysql+pymysql://root:***@localhost
# 50 rows affected.
# [('aDW0001', 'Ailbert', 'Danie', 'Warmisham', 'dwarmishame@soundcloud.com', 'Staff', None),
#  ('aRS0001', 'Ari', 'Rheta', 'Sellek', 'rsellek6@oakley.com', 'Lecturer', None),
#  ('bRM0001', 'Bamby', 'Rubetta', 'Mabbs', 'rmabbs4@xing.com', 'Lecturer', None),
#  ('bS0001', 'Bonny', None, 'Scheffel', 'lscheffel7@taobao.com', 'Professor', None),
#  ('bSH0001', 'Bettina', 'Sonya', 'Higgonet', 'shiggonet2b@163.com', 'Lecturer', None),
#  ('cAL0001', 'Cari', 'Andriana', 'Leask', 'aleask1n@devhub.com', 'Lecturer', None),
#  ('cG0001', 'Clim', None, 'Guislin', 'lguislin2o@chicagotribune.com', 'Professor', None),
#  ('cMW0001', 'Carey', 'Maudie', 'Wyrall', 'mwyrallj@scientificamerican.com', 'Staff', None),
#  ('cS0001', 'Christie', None, 'Siegertsz', 'hsiegertsz21@instagram.com', 'Professor', None),
#  ('cT0001', 'Carmine', None, 'Tolman', 'gtolmanr@slideshare.net', 'Staff', None),
# ...

# %% [markdown]
# ## Testing
#
# Add your tests below. You should test
#
# 1. Successful execution of each procedure.
# 2. Execution of update procedures showing that your constraints prevent incorrect data entry and enforce the defined semantics and behavior.
# 3. ```general_user``` can query the data and call the procedures, but cannot perform ```INSERT```, ```UPDATE```, or ```DELETE```.

# %%
##Testing create_student 
# %%sql
CALL create_student('James','Bob','Doe', 'james.doe@email.com', 2022, @uni_out);
SELECT @uni_out;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# 1 rows affected.
# [('jBD0002',)]

# %%
##Testing update_student 
# %%sql
CALL update_student('jBD0002', 'Jameson', 'Bobson', 'Doeson', 'jameson.doeson@email.com', 2023);
SELECT * FROM student WHERE uni = 'jBD0002';
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# 1 rows affected.
# [('jBD0002', 'Jameson', 'Bobson', 'Doeson', 'jameson.doeson@email.com', 2023, None)]

# %%
##Testing create_employee
# %%sql
CALL create_employee('Jane', 'Marie','Smith', 'jane.smith@email.com', 'Professor', @uni_out);
SELECT @uni_out;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# 1 rows affected.
# [('jMS0001',)]

# %%
##Testing update_employee
# %%sql
CALL update_employee('jMS0001', 'Janey', 'Mary', 'Smithy', 'janey.smithy@email.com', 'Staff');
SELECT * FROM employee WHERE uni = 'jMS0001';
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# 1 rows affected.
# [('jMS0001', 'Janey', 'Mary', 'Smithy', 'janey.smithy@email.com', 'Staff', None)]

# %%
##Testing if duplicate unis are made with constraints
# %%sql
CALL create_student('Jame', 'Bow', 'Don', 'jame.don@email.com', 2022, @uni_out);
SELECT @uni_out;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# 1 rows affected.
# [('jBD0003',)]

# %%
##Testing if invalid employee type works
# %%sql
CALL create_employee('Jules', 'And','Colins', 'jules.colins@email.com', 'Adjunct', @uni_out);
SELECT @uni_out;
# Out:
#  * mysql+pymysql://root:***@localhost
# (pymysql.err.DataError) (1265, "Data truncated for column 'employee_type' at row 1")
# [SQL: CALL create_employee('Jules', 'And','Colins', 'jules.colins@email.com', 'Adjunct', @uni_out);]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
